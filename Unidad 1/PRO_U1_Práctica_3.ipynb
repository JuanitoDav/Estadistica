# %%
maximo1 = max(fabrica1)
minimo1 = min(fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)

print("Estadística descriptiva de la fábrica 1\n", "Media =", media1,
      "\n Mediana =", mediana1, "\n Moda =", moda1, "\n Máximo =", maximo1,
      "\n Mínimo =", minimo1, "\n Rango =", rango1)
# Out:
# Estadística descriptiva de la fábrica 1
#  Media = 72.4063
#  Mediana = 71.99000000000001
#  Moda = 82.73
#  Máximo = 98.8
#  Mínimo = 50.7
#  Rango = 48.099999999999994

# %%
maximo2 = max(fabrica2)
minimo2 = min(fabrica2)
rango2 = maximo2 - minimo2
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)

print("Estadística descriptiva de la fábrica 2\n", "Media =", media2,
      "\n Mediana =", mediana2, "\n Moda =", moda2, "\n Máximo =", maximo2,
      "\n Mínimo =", minimo2, "\n Rango =", rango2)
# Out:
# Estadística descriptiva de la fábrica 2
#  Media = 74.9686
#  Mediana = 74.21000000000001
#  Moda = 71.75
#  Máximo = 99.66
#  Mínimo = 51.3
#  Rango = 48.36

# %% [markdown]
# # Dispersión de los datos

# %%
desviacion_estandar_fabrica1 = stdev(fabrica1)
print(desviacion_estandar_fabrica1)
# Out:
# 14.402611972356356

# %%
desviacion_estandar_fabrica2 = stdev(fabrica2)
print(desviacion_estandar_fabrica2)
# Out:
# 13.365351482187974

# %%
plt.figure(figsize = (8, 6))
plt.hist(fabrica1, bins = 10, alpha = 0.2, color = 'b', edgecolor = "black")
plt.axvline(media1, color = 'b', linestyle = 'dashed', linewidth = 2, label = f'Media=(media1:.2f)')
plt.axvline(mediana1, color = 'r', linestyle = 'dashed', linewidth = 2, label = f'Mediana=(mediana1:.2f)')
plt.axvline(moda1, color = 'y', linestyle = 'dashed', linewidth = 2, label = f'Moda=(moda1:.2f)')
plt.axvline(media1 - desviacion_estandar_fabrica1, color = 'black', linestyle = 'dashed',
            linewidth = 2, label = f'Desv. Estándar=(desviacion_estandar_fabrica1:.2f)')
plt.axvline(media1 + desviacion_estandar_fabrica1, color = 'black', linestyle = 'dashed', linewidth = 2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Producción diaria de la fábrica 1')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.hist(fabrica2, bins = 10, alpha = 0.2, color = 'b', edgecolor = "black")
plt.axvline(media2, color = 'b', linestyle = 'dashed', linewidth = 2, label = f'Media=(media2:.2f)')
plt.axvline(mediana2, color = 'r', linestyle = 'dashed', linewidth = 2, label = f'Mediana=(median2:.2f)')
plt.axvline(moda2, color = 'y', linestyle = 'dashed', linewidth = 2, label = f'Moda=(moda2:.2f)')
plt.axvline(media2 - desviacion_estandar_fabrica2, color = 'black', linestyle = 'dashed',
            linewidth = 2, label = f'Desv. Estándar=(desviacion_estandar_fabrica2:.2f)')
plt.axvline(media2 + desviacion_estandar_fabrica2, color = 'black', linestyle = 'dashed', linewidth = 2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Producción diaria de la fábrica 2')
plt.legend()
plt.show()

# %% [markdown]
# # Densidad

# %%
import seaborn as sns
# La densidad gráfica es una forma de visualizar la distribución de datos en un intérvalo o periodo de tiempo continuo.
# Se basa en un histograma que usa el suavizado de Kernel para trazar valores, lo que permite obtener distribuciones más suaves al reducir el ruido.
# Una curva de densidad muestra la ubicación de la media y la mediana de una distribución.

sns.histplot(x = fabrica1, kde = True, kde_kws = {'bw_adjust': 0.5}, bins = 10)
# Out:
# <Axes: ylabel='Count'>
